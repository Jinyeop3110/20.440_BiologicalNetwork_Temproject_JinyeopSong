# %%
ifnb.list
# Out:
# $CTRL
# An object of class Seurat
# 14053 features across 6548 samples within 1 assay
# Active assay: RNA (14053 features, 2000 variable features)
#
# $STIM
# An object of class Seurat
# 14053 features across 7451 samples within 1 assay
# Active assay: RNA (14053 features, 2000 variable features)

# %%
# load dataset
LoadData("ifnb")

# split the dataset into a list of two seurat objects (stim and CTRL)
ifnb.list <- SplitObject(ifnb, split.by = "stim")

# normalize and identify variable features for each dataset independently
ifnb.list <- lapply(X = ifnb.list, FUN = function(x) {
    x <- NormalizeData(x)
    x <- FindVariableFeatures(x, selection.method = "vst", nfeatures = 2000)
})

# select features that are repeatedly variable across datasets for integration
features <- SelectIntegrationFeatures(object.list = ifnb.list)
# Out:
# An object of class Seurat
# 14053 features across 13999 samples within 1 assay
# Active assay: RNA (14053 features, 0 variable features)

# %%
 FindIntegrationAnchors(object.list = ifnb.list, anchor.features = features)
# Out:
# Scaling features for provided objects
#
# Finding all pairwise anchors
#
# Running CCA
#
# Merging objects
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 16393 anchors
#
# Filtering anchors
#
# 	Retained 6756 anchors
# An AnchorSet object containing 13512 anchors between 2 Seurat objects
#  This can be used as input to IntegrateData.

# %%
ifnb
# Out:
# An object of class Seurat
# 14053 features across 13999 samples within 1 assay
# Active assay: RNA (14053 features, 0 variable features)

# %%
devtools::install_github('satijalab/seurat-data')
# Out:
# ...
# cli (3.6.0 -> 3.6.1) [CRAN]
# Installing 1 packages: cli
# 다운로드된 바이너리 패키지들은 다음의 위치에 있습니다
# 	/var/folders/jx/rq_jr02135l_jt9wtyd2x47c0000gn/T//Rtmp8A9Xug/downloaded_packages
# ── R CMD build ─────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/private/var/folders/jx/rq_jr02135l_jt9wtyd2x47c0000gn/T/Rtmp8A9Xug/remotes1ef24b08b36b/satijalab-seurat-data-d6a8ce6/DESCRIPTION’ (400ms)
# ─  preparing ‘SeuratData’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Omitted ‘LazyData’ from DESCRIPTION
# ─  building ‘SeuratData_0.2.2.tar.gz’

# %%
library(Seurat)
library(SeuratData)
library(patchwork)
# Out:
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# “downloaded length 347020926 != reported length 413266233”
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# “URL 'https://seurat.nygenome.org/src/contrib/ifnb.SeuratData_3.1.0.tar.gz': Timeout of 60 seconds was reached”
# Error in download.file(url, destfile, method, mode = "wb", ...) :
#   download from 'http://seurat.nygenome.org/src/contrib/ifnb.SeuratData_3.1.0.tar.gz' failed
# Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# “패키지 ‘ifnb.SeuratData’를 다운로드 하는데 실패했습니다”
# Error in loadNamespace(name): ‘ifnb.SeuratData’이라고 불리는 패키지가 없습니다
# Traceback:
#
# 1. InstallData("ifnb")
# 2. attachNamespace(ns = pkg)
# 3. asNamespace(ns, base.OK = FALSE)
# 4. getNamespace(ns)
# 5. loadNamespace(name)
# 6. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 7. withOneRestart(expr, restarts[[1L]])
# 8. doWithOneRestart(return(expr), restart)

# %%
InstallData("ifnb")
LoadData("ifnb")

# split the dataset into a list of two seurat objects (stim and CTRL)
ifnb.list <- SplitObject(ifnb, split.by = "stim")

# normalize and identify variable features for each dataset independently
ifnb.list <- lapply(X = ifnb.list, FUN = function(x) {
    x <- NormalizeData(x)
    x <- FindVariableFeatures(x, selection.method = "vst", nfeatures = 2000)
})

# select features that are repeatedly variable across datasets for integration
features <- SelectIntegrationFeatures(object.list = ifnb.list)
# Out:
# An object of class Seurat
# 14053 features across 13999 samples within 1 assay
# Active assay: RNA (14053 features, 0 variable features)

# %%
features
# Out:
#    [1] "HBB"            "HBA2"           "HBA1"           "CCL4"
#    [5] "CCL3"           "CCL7"           "TXN"            "GNLY"
#    [9] "PPBP"           "APOBEC3B"       "VMO1"           "ALAS2"
#   [13] "CCL2"           "CXCL3"          "IFI27"          "MIR155HG"
#   [17] "GZMB"           "PTGDS"          "C1QB"           "IGLL5"
#   [21] "CCL22"          "IL1B"           "IGJ"            "CXCL1"
#   [25] "CCL8"           "G0S2"           "CXCL10"         "HBD"
#   [29] "LYZ"            "SERPINB2"       "IL8"            "CCL5"
#   [33] "HLA-DPB1"       "RAMP1"          "SPP1"           "AL928768.3"
#   [37] "HLA-DRA"        "TSPAN13"        "HLA-DQA1"       "MYC"
#   [41] "CD74"           "FABP5"          "XCL2"           "FCER1A"
#   [45] "HSPA6"          "HLA-DPA1"       "XCL1"           "IDO1"
#   [49] "SPINK1"         "NKG7"           "TVP23A"         "HSPA1B"
#   [53] "HLA-DRB5"       "TIMP1"          "FCGR3A"         "SDS"
# ...

# %%
sum(!ifnb$groups)
# Out:
# [1] 13669

# %%
ifnb$groups<-FetchData(object = ifnb, vars = c('HBB'))>1

# %%
#FetchData(object = ifnb, vars = c('stim'))
#ifnb$groups

random_group_labels <- sample(x = c("g1", "g2"), size = ncol(x = ifnb), replace = TRUE)

# %%
#GetAssayData(ifnb, slot = "counts")
FetchData(object = ifnb, vars = c('HBB'))>1
# Out:
#                  HBB
# AAACATACATTTCC.1 FALSE
# AAACATACCAGAAA.1 FALSE
# AAACATACCTCGCT.1 FALSE
# AAACATACCTGGTA.1 FALSE
# AAACATACGATGAA.1 FALSE
# AAACATACGGCATT.1 FALSE
# AAACATACTGCGTA.1 FALSE
# AAACATACTGCTGA.1 FALSE
# AAACATTGAGTGTC.1 FALSE
# AAACATTGCTTCGC.1 FALSE
# AAACCGTGAGCCAT.1 FALSE
# AAACCGTGGAGGCA.1 FALSE
# AAACCGTGTGCTAG.1 FALSE
# AAACGCACACTTTC.1 FALSE
# AAACGCACAGTACC.1 FALSE
# AAACGCACCAACCA.1 FALSE
# AAACGCACGCTGTA.1 FALSE
# AAACGCACGGGAGT.1 FALSE
# AAACGCACTCGCCT.1 FALSE
# AAACGCTGACCTTT.1 FALSE
# AAACGCTGCAGTTG.1 FALSE
# AAACGCTGCCTAAG.1 FALSE
# AAACGCTGCGTTGA.1 FALSE
# AAACGCTGCTGACA.1 FALSE
# AAACGCTGGATAAG.1 FALSE
# AAACGCTGGGACAG.1 FALSE
# AAACGCTGGGGATG.1 FALSE
# AAACGCTGGGTTTG.1 FALSE
# AAACGCTGTAGCGT.1 FALSE
# AAACGCTGTGCTAG.1 FALSE
# ⋮                ⋮
# TTTCACGATCTCCG.1 FALSE
# TTTCAGTGAGCATC.1 FALSE
# TTTCAGTGATTCGG.1 FALSE
# TTTCAGTGCCACCT.1 FALSE
# TTTCAGTGCGAGAG.1 FALSE
# TTTCAGTGTCACGA.1 FALSE
# TTTCCAGACGAGTT.1  TRUE
# TTTCCAGAGAGCAG.1 FALSE
# ...
